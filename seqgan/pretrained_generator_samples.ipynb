# %%
run main.py
# Out:
# Namespace(cuda=None)
# starting to load to data
# done loading data
# Pretrain with BCE ...
# Epoch [0] Model Loss: 6147.710075
# Epoch [1] Model Loss: 1738.243739
# Epoch [2] Model Loss: 1623.645201
# Epoch [3] Model Loss: 1601.435670
# Epoch [4] Model Loss: 1580.986598
# Epoch [5] Model Loss: 1570.140472
# Epoch [6] Model Loss: 1563.166927
# Epoch [7] Model Loss: 1559.365390
# Epoch [8] Model Loss: 1557.652959
# Epoch [9] Model Loss: 1556.187715
# Pretrain Discriminator ...
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/kushaltirumala/Desktop/code/resesarch/seqgan-multiagent/main.py in <module>()
#     209 for epoch in range(5):
#     210     generate_samples(generator, BATCH_SIZE, GENERATED_NUM, NEGATIVE_FILE)
# --> 211     dis_data_iter = DisDataIter(data, NEGATIVE_FILE, BATCH_SIZE)
#     212     for _ in range(3):
# ...

# %%
samples = generator.sample(BATCH_SIZE, g_sequence_len)

# %%
samples
# Out:
# Variable containing:
# (0 ,.,.) =
#   0.0000  0.0000  0.0000  ...   0.0000  0.0000  0.0000
#   0.7689  0.5547  0.5337  ...   0.5584  0.4645  0.5649
#   0.0045  0.0046  0.0039  ...   0.0044  0.0040  0.0045
#            ...             ⋱             ...
#   0.0365  0.2181  0.0552  ...   0.1708  0.0580  0.1796
#   0.0365  0.2181  0.0552  ...   0.1708  0.0580  0.1796
#   0.0365  0.2181  0.0552  ...   0.1708  0.0580  0.1796
#
# (1 ,.,.) =
#   0.0000  0.0000  0.0000  ...   0.0000  0.0000  0.0000
#   0.7689  0.5547  0.5337  ...   0.5584  0.4645  0.5649
#   0.0045  0.0046  0.0039  ...   0.0044  0.0040  0.0045
#            ...             ⋱             ...
#   0.0365  0.2181  0.0552  ...   0.1708  0.0580  0.1796
#   0.0365  0.2181  0.0552  ...   0.1708  0.0580  0.1796
#   0.0365  0.2181  0.0552  ...   0.1708  0.0580  0.1796
#
# (2 ,.,.) =
#   0.0000  0.0000  0.0000  ...   0.0000  0.0000  0.0000
#   0.7689  0.5547  0.5337  ...   0.5584  0.4645  0.5649
# ...

# %%
from utils import unnormalize, plot_sequences, plot_animation, plot_macrogoals
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-830ce5e55467> in <module>()
# ----> 1 from utils import unnormalize, plot_sequences, plot_animation, plot_macrogoals
#
# ImportError: cannot import name unnormalize

# %%
def draw_data(model_states):
    print("Drawing")
    draw_data = model_states[0, :, :]
    draw_data = draw_data.cpu().numpy()[:, 2:12]
    normal = [50.0, 47.0] * 5
    draw_data = draw_data * normal
    colormap = ['b', 'r', 'g', 'm', 'y']
    plot_sequences([draw_data], macro_goals=None, colormap=colormap, show=True, burn_in=0)

# %%
draw_data(samples.data)
# Out:
# Drawing
# /anaconda/lib/python2.7/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
